# %%
import requests 
from config import omdb_key
from config import tmdb_key
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 999)
import time

# %%
# #from datetime import datetime
# sampledate = "May 29 2000"
# sampledate = pd.to_datetime(sampledate)
# new = sampledate.date()

# %%
def tmdb_request(movie_id):
    #movie_id comes from calling 'imdbID' key from the omdb request
    import requests
    url = "https://api.themoviedb.org/3/movie/" + movie_id + "?language=en-US&api_key=" + tmdb_key
    
    #url = "https://api.themoviedb.org/3/movie/tt2527336"

    payload = "{}"
    response = requests.request("GET", url, data=payload)

    return response.json()

# %%
def omdb_request(movie_title):
    seperator = '+'
    title_url = seperator.join(movie_title.split())
    url = 'http://www.omdbapi.com/?' + 't=' + title_url + '&apikey=' + omdb_key
    r = requests.get(url)
    return r.json()

# %%
def make_int(df_name, column_name):
    empty = []
    
    for index, row in df_name.iterrows():
        if type(row[column_name]) != float:
            plus = row[column_name].split('$')
            dot = plus[-1].split('.')
            number = None

            if len(dot) == 2:
                number = dot[0]+dot[1]
                if number[-1] == 'k':
                    number = number.replace('k', '00')
                else:
                    number = number.replace(',','') + '00000'
            else:
                number = dot[0].replace('k', '000')

            empty.append(int(number))
        else:
            empty.append(int(0))
    df_name[column_name] = empty

# %%
def bom_db(year):
    url = 'https://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=' + str(year)+'&p=.htm'
    r = pd.read_html(requests.get(url).content)
    
    df = r[2]
    
    df.columns = ['Rank', 'Title', 'Studio', 'Worldwide_Gross', 'Domestic_Gross', 
                   'Domestic%','Overseas_Gross' ,'Overseas%']

    df['Year'] = year
    df.drop([0,1], inplace=True)
    df.reset_index(inplace=True)
    df.drop(columns=['index', 'Rank'], inplace=True)
    
    make_int(df, 'Worldwide_Gross')
    make_int(df, 'Domestic_Gross')
    make_int(df, 'Overseas_Gross')
    return df

# %%
testing
# Out:
# {'Title': 'Finding Nemo',
#  'Year': '2003',
#  'Rated': 'G',
#  'Released': '30 May 2003',
#  'Runtime': '100 min',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Director': 'Andrew Stanton, Lee Unkrich(co-director)',
#  'Writer': 'Andrew Stanton (original story by), Andrew Stanton (screenplay by), Bob Peterson (screenplay by), David Reynolds (screenplay by)',
#  'Actors': 'Albert Brooks, Ellen DeGeneres, Alexander Gould, Willem Dafoe',
#  'Plot': 'After his son is captured in the Great Barrier Reef and taken to Sydney, a timid clownfish sets out on a journey to bring him home.',
#  'Language': 'English',
#  'Country': 'USA',
#  'Awards': 'Won 1 Oscar. Another 48 wins & 61 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjMxYzBiNjUtZDliNC00MDAyLTg3N2QtOWNjNmNhZGQzNDg5XkEyXkFqcGdeQXVyNjE2MjQwNjc@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '99%'},
#   {'Source': 'Metacritic', 'Value': '90/100'}],
#  'Metascore': '90',
#  'imdbRating': '8.1',
#  'imdbVotes': '854,049',
#  'imdbID': 'tt0266543',
#  'Type': 'movie',
#  'DVD': '07 May 2013',
#  'BoxOffice': '$380,529,370',
#  'Production': 'Walt Disney Pictures',
#  'Website': 'http://disney.go.com/disneyvideos/animatedfilms/findingnemo/index2.html',
#  'Response': 'True'}

# %%
# for i in range(0, len(df_1989.Title)):
    
#     title_data = omdb_request(df_1989.Title[i]) #Requests omdb to get data about specific movie
#     if title_data['Response'] == 'False':
#         df_1989.loc[i, 'rotton_tomatoes_rating'] = np.nan
#         df_1989.loc[i, 'imdb_rating'] = np.nan
#         df_1989.loc[i, 'meta_score'] = np.nan
#     else:
    
#         if len(title_data['Ratings']) == 3:
#             for rating in title_data['Ratings']:
#                 if rating['Source'] == 'Internet Movie Database':
#                     imdb_score = float(rating['Value'].split('/')[0])
#                 elif rating['Source'] == 'Rotten Tomatoes':
                    
#                     rtom_score = float(rating['Value'].split('%')[0])
                
#                 elif rating['Source'] == 'Metacritic':
#                     metascore = rating['Value'].split('/')[0]
                
                    
            
#             df_1989.loc[i, 'imdb_rating'] = imdb_score
#             df_1989.loc[i, 'rotton_tomatoes_rating'] = rtom_score
#             df_1989.loc[i, 'meta_score'] = metascore
          
#         elif len(title_data['Ratings']) == 2:
#             missingid = 0
#             for rating in title_data['Ratings']:
#                 if rating['Source'] == 'Internet Movie Database':
#                     imdb_score = float(rating['Value'].split('/')[0])
#                     missingid = 1
                    
#                 elif rating['Source'] == 'Rotten Tomatoes':
                    
#                     rtom_score = float(rating['Value'].split('%')[0])
#                     missingid = 2
                
#                 elif rating['Source'] == 'Metacritic':
#                         metascore = rating['Value'].split('/')[0]
#                         missingid = 3
#             if missingid == 2:
                
#                 df_1989.loc[i, 'imdb_rating'] = imdb_score
#                 df_1989.loc[i, 'meta_score'] = np.nan
#                 df_1989.loc[i, 'rotton_tomatoes_rating'] = rtom_score
#             elif missingid ==3:
#                 df_1989.loc[i, 'imdb_rating'] = imdb_score
#                 df_1989.loc[i, 'meta_score'] = metascore
#                 df_1989.loc[i, 'rotton_tomatoes_rating'] = np.nan
            
            
            
            
    #         metascore = float(title_data['Metascore'])
            
    #         rtom_original = title_data['Ratings'][1]['Value']
            
    #         rtom_score = float(rtom_original.split('%')[0])

# %%
def df_with_ratings(year):
    df = bom_db(year) #Creates dataframe using previous function
    #Looping through the title of each movie in the dataframe
    for i in range(0, len(df.Title)):
     
        title_data = omdb_request(df.Title[i]) #Requests omdb to get data about specific movie
        if title_data['Response'] == 'False':
            df.loc[i, 'rotten_tomatoes_rating'] = np.nan
            df.loc[i, 'imdb_rating'] = np.nan
            df.loc[i, 'meta_score'] = np.nan
            df.loc[i, 'actors'] = np.nan
            df.loc[i, 'rating'] = np.nan
            df.loc[i, 'genre'] = np.nan
            df.loc[i, 'director'] = np.nan
            df.loc[i, 'release_date'] = np.nan
            df.loc[i, 'budget'] = np.nan
            
            
            
            
        else:
            imdb_score = 0
            rtom_score = 0
            metascore = 0
            if len(title_data['Ratings']) == 3:
                for rating in title_data['Ratings']:
                    if rating['Source'] == 'Internet Movie Database':
                        imdb_score = float(rating['Value'].split('/')[0])
                    elif rating['Source'] == 'Rotten Tomatoes':
                        
                        rtom_score = float(rating['Value'].split('%')[0])
                    
                    elif rating['Source'] == 'Metacritic':
                        metascore = rating['Value'].split('/')[0]
                    
                        
                
                df.loc[i, 'imdb_rating'] = imdb_score
                df.loc[i, 'rotten_tomatoes_rating'] = rtom_score
                df.loc[i, 'meta_score'] = metascore
                df.loc[i, 'actors'] = title_data['Actors']
                df.loc[i, 'rating'] = title_data['Rated']
                df.loc[i, 'genre'] = title_data['Genre']
                df.loc[i, 'director'] = title_data['Director']
                df.loc[i, 'release_date'] = title_data['Released'].split()[0] + ' ' + title_data['Released'].split()[1]
                
                imdb_id = title_data['imdbID']
                movie_tmdb_info = tmdb_request(imdb_id)
                budget = movie_tmdb_info['budget']
                df.loc[i, 'budget'] = int(budget)  
            
            elif len(title_data['Ratings']) == 2:
                missingid = 0
                for rating in title_data['Ratings']:
                    if rating['Source'] == 'Internet Movie Database':
                        imdb_score = float(rating['Value'].split('/')[0])
                        missingid = 1
                        
                    elif rating['Source'] == 'Rotten Tomatoes':
                        
                        rtom_score = float(rating['Value'].split('%')[0])
                        missingid = 2
                    
                    elif rating['Source'] == 'Metacritic':
                            metascore = rating['Value'].split('/')[0]
                            missingid = 3
                if missingid == 2:
                    
                    df.loc[i, 'imdb_rating'] = imdb_score
                    df.loc[i, 'meta_score'] = np.nan
                    df.loc[i, 'rotten_tomatoes_rating'] = rtom_score
                    df.loc[i, 'actors'] = title_data['Actors']
                    df.loc[i, 'rating'] = title_data['Rated']
                    df.loc[i, 'genre'] = title_data['Genre']
                    df.loc[i, 'director'] = title_data['Director']
                    df.loc[i, 'release_date'] = title_data['Released'].split()[0] + ' ' + title_data['Released'].split()[1]
                    #Calling a different api to get budget 
                    imdb_id = title_data['imdbID']
                    movie_tmdb_info = tmdb_request(imdb_id)
                    budget = movie_tmdb_info['budget']
                    df.loc[i, 'budget'] = int(budget)
                
                elif missingid ==3:
                    df.loc[i, 'imdb_rating'] = imdb_score
                    df.loc[i, 'meta_score'] = metascore
                    df.loc[i, 'rotten_tomatoes_rating'] = np.nan
                    df.loc[i, 'actors'] = title_data['Actors']
                    df.loc[i, 'rating'] = title_data['Rated']
                    df.loc[i, 'genre'] = title_data['Genre']
                    df.loc[i, 'director'] = title_data['Director']
                    df.loc[i, 'release_date'] = title_data['Released'].split()[0] + ' ' + title_data['Released'].split()[1]
                    #Calling a different api to get budget
                    imdb_id = title_data['imdbID']
                    movie_tmdb_info = tmdb_request(imdb_id)
                    budget = movie_tmdb_info['budget']
                    df.loc[i, 'budget'] = int(budget)
            
        time.sleep(0.25)    
    return df

# %%
df1 = df_with_ratings(1989)

# %%
df1
# Out:
#                                  Title Studio  Worldwide_Gross  \
# 0   Indiana Jones and the Last Crusade   Par.        474200000
# 1                               Batman     WB        411300000
# 2           Back to the Future Part II   Uni.        332000000
# 3                   Look Who's Talking   TriS        297000000
# 4                   Dead Poets Society     BV        235900000
# 5                      Lethal Weapon 2     WB        227900000
# 6             Honey, I Shrunk the Kids     BV        222700000
# 7                      Ghostbusters II   Col.        215400000
# 8                   The Little Mermaid     BV        184200000
# 9           Born on the Fourth of July   Uni.        161000000
# 10                The War of the Roses    Fox        160200000
# 11                     Licence to Kill     UA        156200000
# 12                  Driving Miss Daisy     WB        145800000
# 13                          Black Rain   Par.        134200000
# 14                          Parenthood   Uni.        126300000
# 15                         Sea of Love   Uni.        110900000
# 16                     Steel Magnolias   TriS         95900000
# 17                           The Abyss    Fox         89800000
# 18                     Field of Dreams   Uni.         84400000
# 19                          Uncle Buck   Uni.         79300000
# 20                                 K-9   Uni.         78200000
# 21                              Always   Uni.         74100000
# 22                          The 'Burbs   Uni.         49100000
# 23                        Fletch Lives   Uni.         39500000
# 24                          The Fly II    Fox         38900000
# 25                  Do the Right Thing   Uni.         37300000
# 26                                 Dad   Uni.         27500000
# 27                        Say Anything    Fox         21500000
# 28                        Roger and Me     WB          7700000
# 29                         Breaking In  Gold.          1900000
# 30         Distant Voices, Still Lives    Ave           688000
#
#     Domestic_Gross Domestic%  Overseas_Gross Overseas%  Year  imdb_rating  \
# 0        197200000     41.6%       277000000     58.4%  1989          8.2
# 1        251200000     61.1%       160200000     38.9%  1989          7.5
# 2        118500000     35.7%       213500000     64.3%  1989          7.8
# 3        140100000     47.2%       156900000     52.8%  1989          5.8
# 4         95900000     40.6%       140000000     59.4%  1989          8.1
# 5        147300000     64.6%        80600000     35.4%  1989          7.2
# 6        130700000     58.7%        92000000     41.3%  1989          6.3
# 7        112500000     52.2%       102900000     47.8%  1989          6.5
# 8         84400000     45.8%        99800000     54.2%  1989          7.6
# 9         70000000     43.5%        91000000     56.5%  1989          7.2
# 10        86900000     54.2%        73300000     45.8%  1989          6.8
# 11        34700000     22.2%       121500000     77.8%  1989          6.6
# 12       106600000     73.1%        39200000     26.9%  1989          7.4
# 13        46200000     34.4%        88000000     65.6%  1989          6.6
# 14       100000000     79.2%        26300000     20.8%  1989          7.0
# 15        58600000     52.8%        52300000     47.2%  1989          6.8
# 16        83800000     87.3%        12100000     12.7%  1989          7.3
# 17        54200000     60.4%        35500000     39.6%  1989          7.6
# 18        64400000     76.3%        20000000     23.7%  1989          7.5
# 19        66800000     84.2%        12500000     15.8%  1989          7.0
# 20        43200000     55.3%        35000000     44.7%  1989          6.0
# 21        43900000     59.2%        30300000     40.8%  1989          6.4
# 22        36600000     74.5%        12500000     25.5%  1989          6.9
# 23        35200000     89.1%         4300000     10.9%  1989          6.1
# 24        20000000     51.5%        18900000     48.5%  1989          5.0
# 25        27500000     73.9%         9800000     26.1%  1989          7.9
# 26        22100000     80.4%         5400000     19.6%  1989          6.2
# 27        20800000     96.6%          734000      3.4%  1989          7.4
# 28         6700000     87.0%         1000000     13.0%  1989          NaN
# 29         1900000    100.0%               0      0.0%  1989          5.4
# 30          688000    100.0%               0      0.0%  1989          7.5
#
#     rotten_tomatoes_rating meta_score  \
# 0                     88.0         65
# 1                     71.0         69
# 2                     64.0         57
# 3                     59.0         51
# 4                     84.0         79
# 5                     83.0         70
# 6                     75.0         63
# 7                     53.0         56
# 8                     93.0         88
# 9                     88.0         75
# 10                    84.0         79
# 11                    77.0         58
# 12                    82.0         81
# 13                    52.0         56
# 14                    93.0         82
# 15                    78.0         66
# 16                    69.0         56
# 17                    89.0         62
# 18                     NaN         57
# 19                    61.0         51
# 20                    22.0         44
# 21                    67.0         50
# 22                    53.0         45
# 23                    37.0         40
# 24                    27.0         36
# 25                    90.0         91
# 26                    60.0        NaN
# 27                    98.0         85
# 28                     NaN        NaN
# 29                    27.0         42
# 30                    81.0         83
#
#                                                actors rating  \
# 0   Harrison Ford, Sean Connery, Denholm Elliott, ...  PG-13
# 1   Michael Keaton, Jack Nicholson, Kim Basinger, ...  PG-13
# 2   Michael J. Fox, Christopher Lloyd, Lea Thompso...     PG
# 3   John Travolta, Kirstie Alley, Olympia Dukakis,...  PG-13
# 4   Robin Williams, Robert Sean Leonard, Ethan Haw...     PG
# 5   Mel Gibson, Danny Glover, Joe Pesci, Joss Ackland      R
# 6   Rick Moranis, Matt Frewer, Marcia Strassman, K...     PG
# 7   Bill Murray, Dan Aykroyd, Sigourney Weaver, Ha...     PG
# 8   Rene Auberjonois, Christopher Daniel Barnes, J...      G
# 9   Tom Cruise, Raymond J. Barry, Caroline Kava, J...      R
# 10  Michael Douglas, Kathleen Turner, Danny DeVito...      R
# 11  Timothy Dalton, Carey Lowell, Robert Davi, Tal...  PG-13
# 12  Morgan Freeman, Jessica Tandy, Dan Aykroyd, Pa...     PG
# 13  Michael Douglas, Andy Garcia, Ken Takakura, Ka...      R
# 14  Steve Martin, Mary Steenburgen, Dianne Wiest, ...  PG-13
# 15  Al Pacino, Ellen Barkin, John Goodman, Michael...      R
# 16  Sally Field, Dolly Parton, Shirley MacLaine, D...     PG
# 17  Ed Harris, Mary Elizabeth Mastrantonio, Michae...  PG-13
# 18  Kevin Costner, Amy Madigan, Gaby Hoffmann, Ray...     PG
# 19  John Candy, Jean Louisa Kelly, Gaby Hoffmann, ...     PG
# 20   Jim Belushi, Mel Harris, Kevin Tighe, Ed O'Neill  PG-13
# 21  Richard Dreyfuss, Holly Hunter, Brad Johnson, ...     PG
# 22  Tom Hanks, Bruce Dern, Carrie Fisher, Rick Duc...     PG
# 23  Chevy Chase, Hal Holbrook, Julianne Phillips, ...     PG
# 24  Eric Stoltz, Daphne Zuniga, Lee Richardson, Jo...      R
# 25  Danny Aiello, Ossie Davis, Ruby Dee, Richard E...      R
# 26  Jack Lemmon, Ted Danson, Olympia Dukakis, Kath...     PG
# 27  John Cusack, Ione Skye, John Mahoney, Lili Taylor  PG-13
# 28                                                NaN    NaN
# 29  Gabrielle Union, Billy Burke, Richard Cabral, ...  PG-13
# 30  Freda Dowie, Pete Postlethwaite, Angela Walsh,...  PG-13
#
#                                            genre                   director  \
# 0                     Action, Adventure, Fantasy           Steven Spielberg
# 1                              Action, Adventure                 Tim Burton
# 2                      Adventure, Comedy, Sci-Fi            Robert Zemeckis
# 3                                         Comedy             Amy Heckerling
# 4                                  Comedy, Drama                 Peter Weir
# 5                        Action, Crime, Thriller             Richard Donner
# 6              Adventure, Comedy, Family, Sci-Fi               Joe Johnston
# 7                Action, Comedy, Fantasy, Sci-Fi               Ivan Reitman
# 8   Animation, Family, Fantasy, Musical, Romance  Ron Clements, John Musker
# 9                          Biography, Drama, War               Oliver Stone
# 10                               Comedy, Romance               Danny DeVito
# 11                   Action, Adventure, Thriller                  John Glen
# 12                                         Drama            Bruce Beresford
# 13                       Action, Crime, Thriller               Ridley Scott
# 14                                 Comedy, Drama                 Ron Howard
# 15      Crime, Drama, Mystery, Romance, Thriller              Harold Becker
# 16                        Comedy, Drama, Romance               Herbert Ross
# 17   Adventure, Drama, Mystery, Sci-Fi, Thriller              James Cameron
# 18                 Drama, Family, Fantasy, Sport        Phil Alden Robinson
# 19                                        Comedy                John Hughes
# 20                         Action, Comedy, Crime                 Rod Daniel
# 21                              Fantasy, Romance           Steven Spielberg
# 22                     Comedy, Mystery, Thriller                  Joe Dante
# 23                        Comedy, Mystery, Crime            Michael Ritchie
# 24                                Horror, Sci-Fi                Chris Walas
# 25                                 Comedy, Drama                  Spike Lee
# 26                                 Drama, Comedy        Gary David Goldberg
# 27                        Comedy, Drama, Romance              Cameron Crowe
# 28                                           NaN                        NaN
# 29                Action, Crime, Drama, Thriller             James McTeigue
# 30                                  Drama, Music             Terence Davies
#
#    release_date      budget
# 0        24 May  48000000.0
# 1        23 Jun  35000000.0
# 2        22 Nov  40000000.0
# 3        13 Oct   7500000.0
# 4        09 Jun  16400000.0
# 5        07 Jul  25000000.0
# 6        23 Jun  18000000.0
# 7        16 Jun  37000000.0
# 8        17 Nov  40000000.0
# 9        05 Jan  14000000.0
# 10       08 Dec  26000000.0
# 11       14 Jul  32000000.0
# 12       26 Jan   7500000.0
# 13       22 Sep  30000000.0
# 14       02 Aug         0.0
# 15       15 Sep  19000000.0
# 16       22 Nov         0.0
# 17       09 Aug  70000000.0
# 18       05 May         0.0
# 19       16 Aug  15000000.0
# 20       28 Apr  17000000.0
# 21       22 Dec  31000000.0
# 22       17 Feb  18000000.0
# 23       17 Mar   8045760.0
# 24       10 Feb         0.0
# 25       21 Jul   6500000.0
# 26       10 Nov  19000000.0
# 27       14 Apr         0.0
# 28          NaN         NaN
# 29       11 May   6000000.0
# 30       18 Nov         0.0

# %%
def super_df(startyear, endyear):
    years = list(range(startyear, endyear+1))
    combined_df = pd.DataFrame()
    
    for year in years:
        temp_df = df_with_ratings(year)
        combined_df = combined_df.append(temp_df)
    
    combined_df = combined_df.reset_index(drop=True)
    return combined_df

# %%
test_df = super_df(1989, 1991)

# %%
df1991 = df_with_ratings(1991)

# %%
import sqlite3
connection = sqlite3.connect('sampledb.df')
cursor = connection.cursor()

# %%
df1991.to_sql('sampledb', con = connection)
# Out:
# C:\Users\ar344\Anaconda3\lib\site-packages\pandas\core\generic.py:2130: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
df1991
# Out:
#                                      Title Studio Worldwide Gross  \
# 0               Terminator 2: Judgment Day   TriS          $519.8
# 1            Robin Hood: Prince of Thieves     WB          $390.5
# 2                     Beauty and the Beast     BV          $351.9
# 3                                     Hook   TriS          $300.9
# 4                 The Silence of the Lambs  Orion          $272.7
# 5                                      JFK     WB          $205.4
# 6                        The Addams Family   Par.          $191.5
# 7                                Cape Fear   Uni.          $182.3
# 8                               Hot Shots!    Fox          $181.1
# 9                            City Slickers   Col.          $179.0
# 10                 Sleeping with the Enemy    Fox          $175.0
# 11                               Backdraft   Uni.          $152.4
# 12                    Fried Green Tomatoes   Uni.          $119.4
# 13  Star Trek VI: The Undiscovered Country   Par.           $96.9
# 14                             Point Break    Fox           $83.5
# 15                             Dying Young    Fox           $82.3
# 16                            The Hard Way   Uni.           $65.6
# 17                              King Ralph   Uni.           $52.5
# 18                            Jungle Fever   Uni.           $43.9
# 19                            Grand Canyon    Fox           $41.0
# 20      An American Tail: Fievel Goes West   Uni.           $40.8
# 21                         Problem Child 2   Uni.           $32.7
# 22             The People Under the Stairs   Uni.           $31.3
# 23                  Madonna: Truth or Dare  Mira.           $29.0
# 24                            Class Action    Fox           $28.3
# 25                         Only the Lonely    Fox           $25.1
# 26                               Pure Luck   Uni.           $24.9
# 27                               Lionheart   Uni.           $24.3
# 28                            For the Boys    Fox           $23.2
# 29                          Child's Play 3   Uni.           $20.6
# 30                                    Rush    MGM            $7.2
# 31            The Double Life of Veronique  Mira.            $2.0
# 32                                   Trust     FL           $356k
#
#    Domestic Gross Domestic % Overseas Gross Overseas %  Year  imdb_rating  \
# 0          $204.8      39.4%         $315.0      60.6%  1991          8.5
# 1          $165.5      42.4%         $225.0      57.6%  1991          6.9
# 2          $145.9      41.5%         $206.0      58.5%  1991          8.0
# 3          $119.7      39.8%         $181.2      60.2%  1991          6.7
# 4          $130.7      47.9%         $142.0      52.1%  1991          8.6
# 5           $70.4      34.3%         $135.0      65.7%  1991          8.0
# 6          $113.5      59.3%          $78.0      40.7%  1991          6.9
# 7           $79.1      43.4%         $103.2      56.6%  1991          7.3
# 8           $69.5      38.4%         $111.6      61.6%  1991          6.7
# 9          $124.0      69.3%          $55.0      30.7%  1991          6.7
# 10         $101.6      58.1%          $73.4      41.9%  1991          6.2
# 11          $77.9      51.1%          $74.5      48.9%  1991          6.7
# 12          $82.4      69.0%          $37.0      31.0%  1991          7.7
# 13          $74.9      77.3%          $22.0      22.7%  1991          7.2
# 14          $43.2      51.7%          $40.3      48.3%  1991          7.2
# 15          $33.7      40.9%          $48.6      59.1%  1991          6.0
# 16          $25.9      39.5%          $39.7      60.5%  1991          6.3
# 17          $34.0      64.8%          $18.5      35.2%  1991          5.2
# 18          $32.5      74.0%          $11.4      26.0%  1991          6.5
# 19          $33.2      81.1%           $7.7      18.9%  1991          6.9
# 20          $22.2      54.4%          $18.6      45.6%  1991          6.5
# 21          $25.1      76.8%           $7.6      23.2%  1991          4.7
# 22          $24.2      77.2%           $7.1      22.8%  1991          6.4
# 23          $15.0      51.7%          $14.0      48.3%  1991          6.2
# 24          $24.3      85.9%           $4.0      14.1%  1991          6.4
# 25          $21.8      87.0%           $3.3      13.0%  1991          6.4
# 26          $22.6      90.8%           $2.3       9.2%  1991          5.7
# 27          $24.1      99.2%          $193k       0.8%  1991          6.2
# 28          $17.9      77.0%           $5.3      23.0%  1991          6.3
# 29          $15.0      72.8%           $5.6      27.2%  1991          5.1
# 30           $7.2     100.0%            NaN       0.0%  1991          8.1
# 31           $2.0     100.0%            NaN       0.0%  1991          7.8
# 32          $356k     100.0%            NaN       0.0%  1991          6.9
#
#     rotten_tomatoes_rating meta_score  \
# 0                     93.0         75
# 1                     51.0         51
# 2                     94.0         95
# 3                     28.0         52
# 4                     96.0         85
# 5                     83.0         72
# 6                     64.0         57
# 7                     75.0         73
# 8                     83.0         61
# 9                     88.0         70
# 10                    21.0         48
# 11                    74.0         38
# 12                    74.0         64
# 13                    81.0         65
# 14                    68.0         58
# 15                    23.0        NaN
# 16                    74.0        NaN
# 17                    20.0        NaN
# 18                    57.0        NaN
# 19                    76.0         64
# 20                    45.0        NaN
# 21                     7.0        NaN
# 22                    63.0        NaN
# 23                    85.0        NaN
# 24                    75.0         58
# 25                    64.0        NaN
# 26                     9.0         36
# 27                    27.0        NaN
# 28                    43.0        NaN
# 29                    23.0         27
# 30                    89.0         75
# 31                    82.0         86
# 32                    78.0         60
#
#                                                actors rating  \
# 0   Arnold Schwarzenegger, Linda Hamilton, Edward ...      R
# 1   Kevin Costner, Morgan Freeman, Mary Elizabeth ...  PG-13
# 2   Robby Benson, Jesse Corti, Rex Everhart, Angel...      G
# 3   Dustin Hoffman, Robin Williams, Julia Roberts,...     PG
# 4   Jodie Foster, Lawrence A. Bonney, Kasi Lemmons...      R
# 5   Sally Kirkland, Anthony Ramirez, Ray LePere, S...      R
# 6   Anjelica Huston, Raul Julia, Christopher Lloyd...  PG-13
# 7   Robert De Niro, Nick Nolte, Jessica Lange, Jul...      R
# 8   Charlie Sheen, Cary Elwes, Valeria Golino, Llo...  PG-13
# 9   Billy Crystal, Daniel Stern, Bruno Kirby, Patr...  PG-13
# 10  Julia Roberts, Patrick Bergin, Kevin Anderson,...      R
# 11  Kurt Russell, William Baldwin, Robert De Niro,...      R
# 12  Kathy Bates, Mary Stuart Masterson, Mary-Louis...  PG-13
# 13  William Shatner, Leonard Nimoy, DeForest Kelle...     PG
# 14  Patrick Swayze, Keanu Reeves, Gary Busey, Lori...      R
# 15  Julia Roberts, Campbell Scott, Vincent D'Onofr...      R
# 16  Michael J. Fox, James Woods, Stephen Lang, Ann...      R
# 17  John Goodman, Peter O'Toole, John Hurt, Camill...     PG
# 18  Wesley Snipes, Annabella Sciorra, Spike Lee, O...      R
# 19  Danny Glover, Kevin Kline, Steve Martin, Mary ...      R
# 20  Phillip Glasser, James Stewart, Erica Yohn, Ca...      G
# 21  John Ritter, Michael Oliver, Jack Warden, Lara...  PG-13
# 22  Brandon Quintin Adams, Everett McGill, Wendy R...      R
# 23   Madonna, Donna DeLory, Niki Harris, Luis Camacho      R
# 24  Gene Hackman, Mary Elizabeth Mastrantonio, Col...      R
# 25  John Candy, Maureen O'Hara, Ally Sheedy, Kevin...  PG-13
# 26  Martin Short, Danny Glover, Sheila Kelley, Sam...     PG
# 27  Jean-Claude Van Damme, Harrison Page, Deborah ...      R
# 28  Bette Midler, James Caan, George Segal, Patric...      R
# 29  Justin Whalin, Perrey Reeves, Jeremy Sylvers, ...      R
# 30  Chris Hemsworth, Daniel Brühl, Olivia Wilde, A...      R
# 31  Irène Jacob, Halina Gryglaszewska, Kalina Jedr...      R
# 32  Clive Owen, Catherine Keener, Liana Liberato, ...      R
#
#                                              genre  \
# 0                                   Action, Sci-Fi
# 1                Action, Adventure, Drama, Romance
# 2     Animation, Family, Fantasy, Musical, Romance
# 3               Adventure, Comedy, Family, Fantasy
# 4                           Crime, Drama, Thriller
# 5                         Drama, History, Thriller
# 6                                  Comedy, Fantasy
# 7                                  Crime, Thriller
# 8                                   Action, Comedy
# 9                                           Comedy
# 10                                 Drama, Thriller
# 11         Action, Crime, Drama, Mystery, Thriller
# 12                                           Drama
# 13             Action, Adventure, Sci-Fi, Thriller
# 14                         Action, Crime, Thriller
# 15                                  Drama, Romance
# 16                           Action, Comedy, Crime
# 17                                 Comedy, Romance
# 18                                  Drama, Romance
# 19                                    Crime, Drama
# 20  Animation, Adventure, Family, Musical, Western
# 21                                  Comedy, Family
# 22               Comedy, Horror, Mystery, Thriller
# 23                              Documentary, Music
# 24                                 Drama, Thriller
# 25                                 Comedy, Romance
# 26                          Comedy, Crime, Mystery
# 27                     Action, Crime, Drama, Sport
# 28                            Comedy, Drama, Music
# 29                                Horror, Thriller
# 30                 Action, Biography, Drama, Sport
# 31         Drama, Fantasy, Music, Mystery, Romance
# 32                          Crime, Drama, Thriller
#
#                        director release_date
# 0                 James Cameron       03 Jul
# 1                Kevin Reynolds       14 Jun
# 2     Gary Trousdale, Kirk Wise       22 Nov
# 3              Steven Spielberg       11 Dec
# 4                Jonathan Demme       14 Feb
# 5                  Oliver Stone       20 Dec
# 6              Barry Sonnenfeld       22 Nov
# 7               Martin Scorsese       15 Nov
# 8                  Jim Abrahams       31 Jul
# 9                 Ron Underwood       07 Jun
# 10                 Joseph Ruben       08 Feb
# 11                   Ron Howard       24 May
# 12                    Jon Avnet       24 Jan
# 13               Nicholas Meyer       06 Dec
# 14              Kathryn Bigelow       12 Jul
# 15              Joel Schumacher       21 Jun
# 16                  John Badham       08 Mar
# 17                David S. Ward       15 Feb
# 18                    Spike Lee       07 Jun
# 19              Lawrence Kasdan       17 Jan
# 20  Phil Nibbelink, Simon Wells       22 Nov
# 21                 Brian Levant       03 Jul
# 22                   Wes Craven       01 Nov
# 23              Alek Keshishian       24 May
# 24                Michael Apted       15 Mar
# 25               Chris Columbus       24 May
# 26                   Nadia Tass       09 Aug
# 27              Sheldon Lettich       11 Jan
# 28                  Mark Rydell       27 Nov
# 29                  Jack Bender       30 Aug
# 30                   Ron Howard       27 Sep
# 31         Krzysztof Kieslowski       22 Nov
# 32              David Schwimmer       28 Apr

# %%
cursor.execute('''SELECT * FROM sampledb''').fetchall()
# Out:
# [(0,
#   'Terminator 2: Judgment Day',
#   'TriS',
#   '$519.8',
#   '$204.8',
#   '39.4%',
#   '$315.0',
#   '60.6%',
#   1991,
#   8.5,
#   93.0,
#   '75',
#   'Arnold Schwarzenegger, Linda Hamilton, Edward Furlong, Robert Patrick',
#   'R',
#   'Action, Sci-Fi',
#   'James Cameron',
#   '03 Jul'),
#  (1,
#   'Robin Hood: Prince of Thieves',
#   'WB',
#   '$390.5',
#   '$165.5',
#   '42.4%',
#   '$225.0',
#   '57.6%',
#   1991,
#   6.9,
#   51.0,
#   '51',
#   'Kevin Costner, Morgan Freeman, Mary Elizabeth Mastrantonio, Christian Slater',
#   'PG-13',
#   'Action, Adventure, Drama, Romance',
#   'Kevin Reynolds',
#   '14 Jun'),
#  (2,
#   'Beauty and the Beast',
#   'BV',
#   '$351.9',
#   '$145.9',
#   '41.5%',
#   '$206.0',
#   '58.5%',
#   1991,
#   8.0,
#   94.0,
#   '95',
#   'Robby Benson, Jesse Corti, Rex Everhart, Angela Lansbury',
#   'G',
#   'Animation, Family, Fantasy, Musical, Romance',
#   'Gary Trousdale, Kirk Wise',
#   '22 Nov'),
#  (3,
#   'Hook',
#   'TriS',
#   '$300.9',
#   '$119.7',
#   '39.8%',
#   '$181.2',
#   '60.2%',
#   1991,
#   6.7,
#   28.0,
#   '52',
#   'Dustin Hoffman, Robin Williams, Julia Roberts, Bob Hoskins',
#   'PG',
#   'Adventure, Comedy, Family, Fantasy',
#   'Steven Spielberg',
#   '11 Dec'),
#  (4,
#   'The Silence of the Lambs',
#   'Orion',
#   '$272.7',
#   '$130.7',
#   '47.9%',
#   '$142.0',
#   '52.1%',
#   1991,
#   8.6,
#   96.0,
#   '85',
#   'Jodie Foster, Lawrence A. Bonney, Kasi Lemmons, Lawrence T. Wrentz',
#   'R',
#   'Crime, Drama, Thriller',
#   'Jonathan Demme',
#   '14 Feb'),
#  (5,
#   'JFK',
#   'WB',
#   '$205.4',
#   '$70.4',
#   '34.3%',
#   '$135.0',
#   '65.7%',
#   1991,
#   8.0,
#   83.0,
#   '72',
#   'Sally Kirkland, Anthony Ramirez, Ray LePere, Steve Reed',
#   'R',
#   'Drama, History, Thriller',
#   'Oliver Stone',
#   '20 Dec'),
#  (6,
#   'The Addams Family',
#   'Par.',
#   '$191.5',
#   '$113.5',
#   '59.3%',
#   '$78.0',
#   '40.7%',
#   1991,
#   6.9,
#   64.0,
#   '57',
#   'Anjelica Huston, Raul Julia, Christopher Lloyd, Dan Hedaya',
#   'PG-13',
#   'Comedy, Fantasy',
#   'Barry Sonnenfeld',
#   '22 Nov'),
#  (7,
#   'Cape Fear',
#   'Uni.',
#   '$182.3',
#   '$79.1',
#   '43.4%',
#   '$103.2',
#   '56.6%',
#   1991,
#   7.3,
#   75.0,
#   '73',
#   'Robert De Niro, Nick Nolte, Jessica Lange, Juliette Lewis',
#   'R',
#   'Crime, Thriller',
#   'Martin Scorsese',
#   '15 Nov'),
#  (8,
#   'Hot Shots!',
#   'Fox',
#   '$181.1',
#   '$69.5',
#   '38.4%',
#   '$111.6',
#   '61.6%',
#   1991,
#   6.7,
#   83.0,
#   '61',
#   'Charlie Sheen, Cary Elwes, Valeria Golino, Lloyd Bridges',
#   'PG-13',
#   'Action, Comedy',
#   'Jim Abrahams',
#   '31 Jul'),
#  (9,
#   'City Slickers',
#   'Col.',
#   '$179.0',
#   '$124.0',
#   '69.3%',
#   '$55.0',
#   '30.7%',
#   1991,
#   6.7,
#   88.0,
#   '70',
#   'Billy Crystal, Daniel Stern, Bruno Kirby, Patricia Wettig',
#   'PG-13',
#   'Comedy',
#   'Ron Underwood',
#   '07 Jun'),
#  (10,
#   'Sleeping with the Enemy',
#   'Fox',
#   '$175.0',
#   '$101.6',
#   '58.1%',
#   '$73.4',
#   '41.9%',
#   1991,
#   6.2,
#   21.0,
#   '48',
#   'Julia Roberts, Patrick Bergin, Kevin Anderson, Elizabeth Lawrence',
#   'R',
#   'Drama, Thriller',
#   'Joseph Ruben',
#   '08 Feb'),
#  (11,
#   'Backdraft',
#   'Uni.',
#   '$152.4',
#   '$77.9',
#   '51.1%',
#   '$74.5',
#   '48.9%',
#   1991,
#   6.7,
#   74.0,
#   '38',
#   'Kurt Russell, William Baldwin, Robert De Niro, Donald Sutherland',
#   'R',
#   'Action, Crime, Drama, Mystery, Thriller',
#   'Ron Howard',
#   '24 May'),
#  (12,
#   'Fried Green Tomatoes',
#   'Uni.',
#   '$119.4',
#   '$82.4',
#   '69.0%',
#   '$37.0',
#   '31.0%',
#   1991,
#   7.7,
#   74.0,
#   '64',
#   'Kathy Bates, Mary Stuart Masterson, Mary-Louise Parker, Jessica Tandy',
#   'PG-13',
#   'Drama',
#   'Jon Avnet',
#   '24 Jan'),
#  (13,
#   'Star Trek VI: The Undiscovered Country',
#   'Par.',
#   '$96.9',
#   '$74.9',
#   '77.3%',
#   '$22.0',
#   '22.7%',
#   1991,
#   7.2,
#   81.0,
#   '65',
#   'William Shatner, Leonard Nimoy, DeForest Kelley, James Doohan',
#   'PG',
#   'Action, Adventure, Sci-Fi, Thriller',
#   'Nicholas Meyer',
#   '06 Dec'),
#  (14,
#   'Point Break',
#   'Fox',
#   '$83.5',
#   '$43.2',
#   '51.7%',
#   '$40.3',
#   '48.3%',
#   1991,
#   7.2,
#   68.0,
#   '58',
#   'Patrick Swayze, Keanu Reeves, Gary Busey, Lori Petty',
#   'R',
#   'Action, Crime, Thriller',
#   'Kathryn Bigelow',
#   '12 Jul'),
#  (15,
#   'Dying Young',
#   'Fox',
#   '$82.3',
#   '$33.7',
#   '40.9%',
#   '$48.6',
#   '59.1%',
#   1991,
#   6.0,
#   23.0,
#   None,
#   "Julia Roberts, Campbell Scott, Vincent D'Onofrio, Colleen Dewhurst",
#   'R',
#   'Drama, Romance',
#   'Joel Schumacher',
#   '21 Jun'),
#  (16,
#   'The Hard Way',
#   'Uni.',
#   '$65.6',
#   '$25.9',
#   '39.5%',
#   '$39.7',
#   '60.5%',
#   1991,
#   6.3,
#   74.0,
#   None,
#   'Michael J. Fox, James Woods, Stephen Lang, Annabella Sciorra',
#   'R',
#   'Action, Comedy, Crime',
#   'John Badham',
#   '08 Mar'),
#  (17,
#   'King Ralph',
#   'Uni.',
#   '$52.5',
#   '$34.0',
#   '64.8%',
#   '$18.5',
#   '35.2%',
#   1991,
#   5.2,
#   20.0,
#   None,
#   "John Goodman, Peter O'Toole, John Hurt, Camille Coduri",
#   'PG',
#   'Comedy, Romance',
#   'David S. Ward',
#   '15 Feb'),
#  (18,
#   'Jungle Fever',
#   'Uni.',
#   '$43.9',
#   '$32.5',
#   '74.0%',
#   '$11.4',
#   '26.0%',
#   1991,
#   6.5,
#   57.0,
#   None,
#   'Wesley Snipes, Annabella Sciorra, Spike Lee, Ossie Davis',
#   'R',
#   'Drama, Romance',
#   'Spike Lee',
#   '07 Jun'),
#  (19,
#   'Grand Canyon',
#   'Fox',
#   '$41.0',
#   '$33.2',
#   '81.1%',
#   '$7.7',
#   '18.9%',
#   1991,
#   6.9,
#   76.0,
#   '64',
#   'Danny Glover, Kevin Kline, Steve Martin, Mary McDonnell',
#   'R',
#   'Crime, Drama',
#   'Lawrence Kasdan',
#   '17 Jan'),
#  (20,
#   'An American Tail: Fievel Goes West',
#   'Uni.',
#   '$40.8',
#   '$22.2',
#   '54.4%',
#   '$18.6',
#   '45.6%',
#   1991,
#   6.5,
#   45.0,
#   None,
#   'Phillip Glasser, James Stewart, Erica Yohn, Cathy Cavadini',
#   'G',
#   'Animation, Adventure, Family, Musical, Western',
#   'Phil Nibbelink, Simon Wells',
#   '22 Nov'),
#  (21,
#   'Problem Child 2',
#   'Uni.',
#   '$32.7',
#   '$25.1',
#   '76.8%',
#   '$7.6',
#   '23.2%',
#   1991,
#   4.7,
#   7.0,
#   None,
#   'John Ritter, Michael Oliver, Jack Warden, Laraine Newman',
#   'PG-13',
#   'Comedy, Family',
#   'Brian Levant',
#   '03 Jul'),
#  (22,
#   'The People Under the Stairs',
#   'Uni.',
#   '$31.3',
#   '$24.2',
#   '77.2%',
#   '$7.1',
#   '22.8%',
#   1991,
#   6.4,
#   63.0,
#   None,
#   'Brandon Quintin Adams, Everett McGill, Wendy Robie, A.J. Langer',
#   'R',
#   'Comedy, Horror, Mystery, Thriller',
#   'Wes Craven',
#   '01 Nov'),
#  (23,
#   'Madonna: Truth or Dare',
#   'Mira.',
#   '$29.0',
#   '$15.0',
#   '51.7%',
#   '$14.0',
#   '48.3%',
#   1991,
#   6.2,
#   85.0,
#   None,
#   'Madonna, Donna DeLory, Niki Harris, Luis Camacho',
#   'R',
#   'Documentary, Music',
#   'Alek Keshishian',
#   '24 May'),
#  (24,
#   'Class Action',
#   'Fox',
#   '$28.3',
#   '$24.3',
#   '85.9%',
#   '$4.0',
#   '14.1%',
#   1991,
#   6.4,
#   75.0,
#   '58',
#   'Gene Hackman, Mary Elizabeth Mastrantonio, Colin Friels, Joanna Merlin',
#   'R',
#   'Drama, Thriller',
#   'Michael Apted',
#   '15 Mar'),
#  (25,
#   'Only the Lonely',
#   'Fox',
#   '$25.1',
#   '$21.8',
#   '87.0%',
#   '$3.3',
#   '13.0%',
#   1991,
#   6.4,
#   64.0,
#   None,
#   "John Candy, Maureen O'Hara, Ally Sheedy, Kevin Dunn",
#   'PG-13',
#   'Comedy, Romance',
#   'Chris Columbus',
#   '24 May'),
#  (26,
#   'Pure Luck',
#   'Uni.',
#   '$24.9',
#   '$22.6',
#   '90.8%',
#   '$2.3',
#   '9.2%',
#   1991,
#   5.7,
#   9.0,
#   '36',
#   'Martin Short, Danny Glover, Sheila Kelley, Sam Wanamaker',
#   'PG',
#   'Comedy, Crime, Mystery',
#   'Nadia Tass',
#   '09 Aug'),
#  (27,
#   'Lionheart',
#   'Uni.',
#   '$24.3',
#   '$24.1',
#   '99.2%',
#   '$193k',
#   '0.8%',
#   1991,
#   6.2,
#   27.0,
#   None,
#   'Jean-Claude Van Damme, Harrison Page, Deborah Rennard, Lisa Pelikan',
#   'R',
#   'Action, Crime, Drama, Sport',
#   'Sheldon Lettich',
#   '11 Jan'),
#  (28,
#   'For the Boys',
#   'Fox',
#   '$23.2',
#   '$17.9',
#   '77.0%',
#   '$5.3',
#   '23.0%',
#   1991,
#   6.3,
#   43.0,
#   None,
#   "Bette Midler, James Caan, George Segal, Patrick O'Neal",
#   'R',
#   'Comedy, Drama, Music',
#   'Mark Rydell',
#   '27 Nov'),
#  (29,
#   "Child's Play 3",
#   'Uni.',
#   '$20.6',
#   '$15.0',
#   '72.8%',
#   '$5.6',
#   '27.2%',
#   1991,
#   5.1,
#   23.0,
#   '27',
#   'Justin Whalin, Perrey Reeves, Jeremy Sylvers, Travis Fine',
#   'R',
#   'Horror, Thriller',
#   'Jack Bender',
#   '30 Aug'),
#  (30,
#   'Rush',
#   'MGM',
#   '$7.2',
#   '$7.2',
#   '100.0%',
#   None,
#   '0.0%',
#   1991,
#   8.1,
#   89.0,
#   '75',
#   'Chris Hemsworth, Daniel Brühl, Olivia Wilde, Alexandra Maria Lara',
#   'R',
#   'Action, Biography, Drama, Sport',
#   'Ron Howard',
#   '27 Sep'),
#  (31,
#   'The Double Life of Veronique',
#   'Mira.',
#   '$2.0',
#   '$2.0',
#   '100.0%',
#   None,
#   '0.0%',
#   1991,
#   7.8,
#   82.0,
#   '86',
#   'Irène Jacob, Halina Gryglaszewska, Kalina Jedrusik, Aleksander Bardini',
#   'R',
#   'Drama, Fantasy, Music, Mystery, Romance',
#   'Krzysztof Kieslowski',
#   '22 Nov'),
#  (32,
#   'Trust',
#   'FL',
#   '$356k',
#   '$356k',
#   '100.0%',
#   None,
#   '0.0%',
#   1991,
#   6.9,
#   78.0,
#   '60',
#   'Clive Owen, Catherine Keener, Liana Liberato, Jason Clarke',
#   'R',
#   'Crime, Drama, Thriller',
#   'David Schwimmer',
#   '28 Apr')]

# %%
cursor.execute('''SELECT Title FROM sampledb WHERE imdb_rating > 8.2''').fetchall()
# Out:
# [('Terminator 2: Judgment Day',), ('The Silence of the Lambs',)]
