# %%
import pandas as pd

# %%
df = pd.read_csv('df2000-01')

# %%
df
# Out:
#      Unnamed: 0 Domestic%  Domestic_Gross Overseas%  Overseas_Gross  Studio  \
# 0             0     39.4%       215400000     60.6%       331000000    Par.
# 1             1     40.8%       187700000     59.2%       272900000      DW
# 2             2     54.4%       233600000     45.6%       196000000     Fox
# 3             3     48.9%       182800000     51.1%       191300000    Par.
# 4             4     39.4%       137700000     60.6%       212100000      BV
# 5             5     75.3%       260000000     24.7%        85100000    Uni.
# 6             6     50.3%       166200000     49.7%       164200000    Uni.
# 7             7     55.6%       182600000     44.4%       146100000      WB
# 8             8     53.1%       157300000     46.9%       139000000     Fox
# 9             9     53.3%       155500000     46.7%       136000000      DW
# 10           10     56.5%       157000000     43.5%       121000000   Mira.
# ...
