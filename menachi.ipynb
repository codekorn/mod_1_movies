# %%
import io, os, sys, types
from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell
from fun import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-38bba3ed3c93> in <module>
#       3 from nbformat import read
#       4 from IPython.core.interactiveshell import InteractiveShell
# ----> 5 from fun import *
#
# ModuleNotFoundError: No module named 'fun'

# %%
import import_ipynb
from fun import *

# %%
df_2014.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-669a64a54d8d> in <module>
# ----> 1 df_2014.describe()
#
# NameError: name 'df_2014' is not defined

# %%
import pandas as pd

# %%
df1 = pd.read_csv('df2000-01')

# %%
df = pd.read_csv('df89-99')

# %%
df = df.append(df1)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df
# Out:
#     Domestic%  Domestic_Gross Overseas%  Overseas_Gross  Studio  \
# 0       41.6%       197200000     58.4%       277000000    Par.
# 1       61.1%       251200000     38.9%       160200000      WB
# 2       35.7%       118500000     64.3%       213500000    Uni.
# 3       47.2%       140100000     52.8%       156900000    TriS
# 4       40.6%        95900000     59.4%       140000000      BV
# 5       64.6%       147300000     35.4%        80600000      WB
# 6       58.7%       130700000     41.3%        92000000      BV
# 7       52.2%       112500000     47.8%       102900000    Col.
# 8       45.8%        84400000     54.2%        99800000      BV
# 9       43.5%        70000000     56.5%        91000000    Uni.
# 10      54.2%        86900000     45.8%        73300000     Fox
# 11      22.2%        34700000     77.8%       121500000      UA
# 12      73.1%       106600000     26.9%        39200000      WB
# 13      34.4%        46200000     65.6%        88000000    Par.
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#       index Domestic%  Domestic_Gross Overseas%  Overseas_Gross  Studio  \
# 0         0     41.6%       197200000     58.4%       277000000    Par.
# 1         1     61.1%       251200000     38.9%       160200000      WB
# 2         2     35.7%       118500000     64.3%       213500000    Uni.
# 3         3     47.2%       140100000     52.8%       156900000    TriS
# 4         4     40.6%        95900000     59.4%       140000000      BV
# 5         5     64.6%       147300000     35.4%        80600000      WB
# 6         6     58.7%       130700000     41.3%        92000000      BV
# 7         7     52.2%       112500000     47.8%       102900000    Col.
# 8         8     45.8%        84400000     54.2%        99800000      BV
# 9         9     43.5%        70000000     56.5%        91000000    Uni.
# 10       10     54.2%        86900000     45.8%        73300000     Fox
# 11       11     22.2%        34700000     77.8%       121500000      UA
# ...
